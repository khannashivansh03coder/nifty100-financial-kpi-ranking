# %%
import sys

sys.path.insert(
    0,
    "/Users/shivanshkhanna/Documents/nifty100_project"
)

print(sys.path[0])
# Out:
# /Users/shivanshkhanna/Documents/nifty100_project

# %%
from src.analytics import ratios

ratios.net_profit_margin(100, 1000)
# Out:
# 10.0

# %%
from src.analytics.cashflow_kpis import *

free_cash_flow(100, -40)
# Out:
# 60

# %%
capex_intensity(-200, 1000)
# Out:
# 20.0

# %%
capital_allocation_pattern(100, -50, -20)
# Out:
# 'Reinvestor'

# %%
from src.analytics.cashflow_kpis import free_cash_flow
