# %%
import pandas as pd

pros = pd.read_excel("data/raw/prosandcons.xlsx", header=1)

print(pros.columns.tolist())
pros.head()
# Out:
# ['id', 'company_id', 'pros', 'cons']
#    id company_id                                               pros  \
# 0   1   HDFCBANK           Company is expected to give good quarter
# 1   2   HDFCBANK  Company has delivered good profit growth of 23...
# 2   3   HDFCBANK  Company has been maintaining a healthy dividen...
# 3   4   HDFCBANK  Company's median sales growth is 16.4% of last...
# 4   5    SBILIFE                       Company is almost debt free.
#
#                                                 cons
# 0      Stock is trading at 2.76 times its book value
# 1           Company has low interest coverage ratio.
# 2         Contingent liabilities of Rs.24,09,821 Cr.
# 3  Earnings include an other income of Rs.1,55,87...
# 4      Stock is trading at 9.11 times its book value
